# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
IceCream = pd.read_csv('IceCreamData.csv')

IceCream.info()

sns.jointplot( x ='Temperature',y = 'Revenue', data = IceCream , color = 'red')

sns.pairplot(IceCream)

sns.lmplot( x ='Temperature',y = 'Revenue', data = IceCream)

X = IceCream[['Temperature']]
y = IceCream['Revenue']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

from sklearn.linear_model import LinearRegression

regressor = LinearRegression(fit_intercept = True)
regressor.fit(X_train, y_train)

print('m_coeff = ',regressor.coef_ )
print('b_coeff = ',regressor.intercept_ )

y_predict = regressor.predict(X_test)

plt.scatter(X_train, y_train, color= 'green')
plt.plot(X_train, regressor.predict(X_train), color= 'red')

plt.ylabel('Revenue [$]')
plt.xlabel('Temprature [degC]')
plt.title('Revenue Gen vs. Temp (Training)')
# Out:
# m_coeff =  [21.47055423]
# b_coeff =  43.44514341936974
# Text(0.5, 1.0, 'Revenue Gen vs. Temp (Training)')

# %%
Temp = 60.0

Revenue = regressor.predict(np.array([Temp]).reshape(1, 1))
Revenue
# Out:
# array([1331.67839701])
